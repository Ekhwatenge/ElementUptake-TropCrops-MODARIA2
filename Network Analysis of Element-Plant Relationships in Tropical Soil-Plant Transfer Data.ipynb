# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('iaea-modaria-ii-tropical-dataset.csv', header=None)

# Preview the data
df.head()
# Out:
#        0        1             2            3                  4            5   \
# 0  Record  Element  Radionuclide  Common name         Latin name  Compartment
# 1       1       Cr           NaN       Potato  Solanum tuberosum       Tubers
# 2       2       Co           NaN       Potato  Solanum tuberosum       Tubers
# 3       3       Ni           NaN       Potato  Solanum tuberosum       Tubers
# 4       4       Cu           NaN       Potato  Solanum tuberosum       Tubers
#
#          6           7     8       9   ...   31       32        33        34  \
# 0        CR  Uncert._CR  N_CR  Min_CR  ...   OM  Exch. K  Exch. Ca  Exch. Mg
# 1  3.60E-02         NaN   NaN     NaN  ...  NaN      NaN       NaN       NaN
# 2  1.70E-02         NaN   NaN     NaN  ...  NaN      NaN       NaN       NaN
# 3  3.70E-02         NaN   NaN     NaN  ...  NaN      NaN       NaN       NaN
# 4  2.50E-01         NaN   NaN     NaN  ...  NaN      NaN       NaN       NaN
#
# ...

# %%
# List of all column names as per the dataset documentation
column_names = [
    'Record', 'Element', 'Radionuclide', 'Common name', 'Latin name', 'Compartment', 'CR', 'Uncert._CR', 'N_CR',
    'Min_CR', 'Max_CR', 'C_plant', 'Uncert._C_plant', 'N_plant', 'C_soil', 'Uncert._C_soil', 'N_soil',
    'Country', 'Site', 'K-G class', 'Contamination', 'Experiment', 'Year', 'Growth stage', 'Dry fraction',
    'Preparation', 'Soil depth', 'Texture', 'Sand', 'Silt', 'Clay', 'OM', 'Exch. K', 'Exch. Ca', 'Exch. Mg',
    'CEC', 'pH', 'QC meas.', 'QC sampl.', 'QC equip.', 'Reference'
]

# %%
# we need to do abit of cleaning by Keeping only rows with valid Element, Latin name, and CR
df_clean = df[['Element', 'Latin name', 'Common name', 'Compartment', 'CR']].copy()
df_clean = df_clean.dropna(subset=['Element', 'Latin name', 'CR'])

# Convert CR to numeric, coerce errors (e.g. empty or invalid) to NaN, then drop them
df_clean['CR'] = pd.to_numeric(df_clean['CR'], errors='coerce')
df_clean = df_clean.dropna(subset=['CR'])

# Optional: Remove zero or negative CRs (if scientifically justified)
df_clean = df_clean[df_clean['CR'] > 0]

df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # we need to do abit of cleaning by Keeping only rows with valid Element, Latin name, and CR
# ----> 2 df_clean = df[['Element', 'Latin name', 'Common name', 'Compartment', 'CR']].copy()
#       3 df_clean = df_clean.dropna(subset=['Element', 'Latin name', 'CR'])
#       5 # Convert CR to numeric, coerce errors (e.g. empty or invalid) to NaN, then drop them
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# ...
